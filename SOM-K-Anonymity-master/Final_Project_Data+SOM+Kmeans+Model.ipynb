# %%
from datetime import datetime

from data import Data
from minisom import MiniSom
import matplotlib.pyplot as plt

# %%
quasi_identifiers = ['age', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']
features = data.X[quasi_identifiers]
target = data.y

#要調整
width=10
height=10
sigma=.9
lr=.2
#epochs=1e5
epochs = 10

verbose=True
log = 1000

# %% [markdown]
# # Data + SOM

# %%
som_start=datetime.now()

data = Data()
som = MiniSom(width, height, features.shape[1], sigma, lr)
som.train_random(features.values, int(epochs), verbose=True)

out = []
for step, (X, y) in enumerate(zip(features.values, target)):
    new_X = som.winner(X)
    out.append((new_X, X, y))
    if(verbose == True and step % log == 0):
        print(f'*Creating SOM: [{step}/{features.shape[0]}]')
som_data = np.array(out)

new_data = []
new_X = []
X = []
y = []
for i in range(0, len(som_data[:,0])):
    new_X.append(np.asarray(som_data[:,0][i]))
    X.append(np.asarray(som_data[:,1][i]))
    y.append(np.asarray(som_data[:,2][i]))
new_data = (new_X, X, y)

print("Time required for SOM: " + str(datetime.now()-som_start))

new_data
# Out:
#  [ 10 / 10 ] 100% - 0:00:00 left
#  quantization error: 9789711.832018306
#  topographic error: 0.061452390429437
# *Creating SOM: [0/45222]
# *Creating SOM: [1000/45222]
# *Creating SOM: [2000/45222]
# *Creating SOM: [3000/45222]
# *Creating SOM: [4000/45222]
# *Creating SOM: [5000/45222]
# *Creating SOM: [6000/45222]
# *Creating SOM: [7000/45222]
# *Creating SOM: [8000/45222]
# *Creating SOM: [9000/45222]
# *Creating SOM: [10000/45222]
# *Creating SOM: [11000/45222]
# *Creating SOM: [12000/45222]
# *Creating SOM: [13000/45222]
# *Creating SOM: [14000/45222]
# *Creating SOM: [15000/45222]
# *Creating SOM: [16000/45222]
# *Creating SOM: [17000/45222]
# *Creating SOM: [18000/45222]
# *Creating SOM: [19000/45222]
# *Creating SOM: [20000/45222]
# *Creating SOM: [21000/45222]
# *Creating SOM: [22000/45222]
# *Creating SOM: [23000/45222]
# *Creating SOM: [24000/45222]
# *Creating SOM: [25000/45222]
# *Creating SOM: [26000/45222]
# *Creating SOM: [27000/45222]
# *Creating SOM: [28000/45222]
# *Creating SOM: [29000/45222]
# *Creating SOM: [30000/45222]
# *Creating SOM: [31000/45222]
# *Creating SOM: [32000/45222]
# *Creating SOM: [33000/45222]
# *Creating SOM: [34000/45222]
# *Creating SOM: [35000/45222]
# *Creating SOM: [36000/45222]
# *Creating SOM: [37000/45222]
# *Creating SOM: [38000/45222]
# *Creating SOM: [39000/45222]
# *Creating SOM: [40000/45222]
# *Creating SOM: [41000/45222]
# *Creating SOM: [42000/45222]
# *Creating SOM: [43000/45222]
# *Creating SOM: [44000/45222]
# *Creating SOM: [45000/45222]
# Time required for SOM: 0:00:10.876981
# ([array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 2], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 2], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 4], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 4], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 4], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([6, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 4], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 4], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 2], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 4], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 4], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([6, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([0, 4], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 4], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 2], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 4], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 2], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 2], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 2], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([3, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([3, 2], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   array([5, 9], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([6, 8], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([4, 3], dtype=int64),
#   array([5, 3], dtype=int64),
#   ...],
#  [array([27,  8,  0,  0, 40], dtype=int64),
#   array([27, 13,  0,  0, 40], dtype=int64),
#   array([   27,     1, 41310,     0,    24], dtype=int64),
#   array([35, 10,  0,  0, 50], dtype=int64),
#   array([44, 10,  0,  0, 45], dtype=int64),
#   array([   71,    13, 11678,     0,    45], dtype=int64),
#   array([50,  9,  0,  0, 60], dtype=int64),
#   array([49,  9,  0,  0, 48], dtype=int64),
#   array([52,  9,  0,  0, 52], dtype=int64),
#   array([57, 14,  0,  0, 40], dtype=int64),
#   array([23, 10,  0,  0, 45], dtype=int64),
#   array([39, 12,  0,  0, 20], dtype=int64),
#   array([37, 10,  0,  0, 40], dtype=int64),
#   array([54,  9,  0,  0, 36], dtype=int64),
#   array([44, 10,  0,  0, 40], dtype=int64),
#   array([19, 10,  0,  0, 30], dtype=int64),
#   array([61, 15,  0,  0, 50], dtype=int64),
#   array([22, 12,  0,  0, 40], dtype=int64),
#   array([53,  4,  0,  0, 40], dtype=int64),
#   array([38, 12,  0,  0, 40], dtype=int64),
#   array([57, 14,  0,  0, 40], dtype=int64),
#   array([23, 10,  0,  0, 40], dtype=int64),
#   array([23,  9,  0,  0, 40], dtype=int64),
#   array([36, 10,  0,  0, 50], dtype=int64),
#   array([42,  9,  0,  0, 50], dtype=int64),
#   array([43, 10,  0,  0, 50], dtype=int64),
#   array([45,  9,  0,  0, 32], dtype=int64),
#   array([40, 13,  0,  0, 50], dtype=int64),
#   array([27, 10,  0,  0, 40], dtype=int64),
#   array([46,  9,  0,  0, 48], dtype=int64),
#   array([37, 13,  0,  0, 15], dtype=int64),
#   array([47,  9,  0,  0, 40], dtype=int64),
#   array([30, 11,  0,  0, 50], dtype=int64),
#   array([57, 14,  0,  0, 38], dtype=int64),
#   array([43, 14,  0,  0, 40], dtype=int64),
#   array([33, 13,  0,  0, 40], dtype=int64),
#   array([46, 10,  0,  0, 40], dtype=int64),
#   array([39,  9,  0,  0, 40], dtype=int64),
#   array([24, 11,  0,  0, 40], dtype=int64),
#   array([18,  7,  0,  0, 21], dtype=int64),
#   array([35,  9,  0,  0, 40], dtype=int64),
#   array([50, 14,  0,  0, 55], dtype=int64),
#   array([47, 14,  0,  0, 40], dtype=int64),
#   array([23,  9,  0,  0, 40], dtype=int64),
#   array([53,  6,  0,  0, 40], dtype=int64),
#   array([46, 10,  0,  0, 52], dtype=int64),
#   array([47, 12,  0,  0, 40], dtype=int64),
#   array([26,  9,  0,  0, 40], dtype=int64),
#   array([ 50,  10,   0, 880,  40], dtype=int64),
#   array([20,  9,  0,  0, 30], dtype=int64),
#   array([22, 10,  0,  0, 20], dtype=int64),
#   array([  50,    9, 3103,    0,   40], dtype=int64),
#   array([27,  9,  0,  0, 40], dtype=int64),
#   array([18, 10,  0,  0, 10], dtype=int64),
#   array([19, 10,  0,  0, 35], dtype=int64),
#   array([20,  9,  0,  0, 60], dtype=int64),
#   array([30,  9,  0,  0, 40], dtype=int64),
#   array([27,  9,  0,  0, 40], dtype=int64),
#   array([26,  6,  0,  0, 40], dtype=int64),
#   array([17,  6,  0,  0, 35], dtype=int64),
#   array([34,  9,  0,  0, 40], dtype=int64),
#   array([32, 14,  0,  0, 20], dtype=int64),
#   array([  39,    9, 2977,    0,   40], dtype=int64),
#   array([41,  9,  0,  0, 45], dtype=int64),
#   array([39,  9,  0,  0, 40], dtype=int64),
#   array([46, 10,  0,  0, 40], dtype=int64),
#   array([46,  1,  0,  0, 40], dtype=int64),
#   array([52, 10,  0,  0, 40], dtype=int64),
#   array([73, 10,  0,  0, 11], dtype=int64),
#   array([28, 13,  0,  0, 60], dtype=int64),
#   array([58,  5,  0,  0, 50], dtype=int64),
#   array([53, 10,  0,  0, 40], dtype=int64),
#   array([43, 10,  0,  0, 40], dtype=int64),
#   array([40,  5,  0,  0, 30], dtype=int64),
#   array([28, 13,  0,  0, 45], dtype=int64),
#   array([53, 11,  0,  0, 40], dtype=int64),
#   array([41, 13,  0,  0, 40], dtype=int64),
#   array([55,  9,  0,  0, 60], dtype=int64),
#   array([37,  4,  0,  0, 44], dtype=int64),
#   array([58, 13,  0,  0, 40], dtype=int64),
#   array([32,  9,  0,  0, 40], dtype=int64),
#   array([28, 13,  0,  0, 50], dtype=int64),
#   array([  28,   10, 3325,    0,   50], dtype=int64),
#   array([26, 10,  0,  0, 40], dtype=int64),
#   array([45,  6,  0,  0, 40], dtype=int64),
#   array([27, 12,  0,  0, 40], dtype=int64),
#   array([32, 11,  0,  0, 40], dtype=int64),
#   array([51, 13,  0,  0, 55], dtype=int64),
#   array([  60,    9, 3103,    0,   35], dtype=int64),
#   array([  35,   13, 4386,    0,   47], dtype=int64),
#   array([29,  9,  0,  0, 56], dtype=int64),
#   array([41, 13,  0,  0, 40], dtype=int64),
#   array([22,  9,  0,  0, 60], dtype=int64),
#   array([19,  8,  0,  0, 30], dtype=int64),
#   array([19,  9,  0,  0, 30], dtype=int64),
#   array([27, 10,  0,  0, 40], dtype=int64),
#   array([41, 10,  0,  0, 50], dtype=int64),
#   array([21, 10,  0,  0, 65], dtype=int64),
#   array([35,  9,  0,  0, 40], dtype=int64),
#   array([41,  9,  0,  0, 40], dtype=int64),
#   array([39, 10,  0,  0, 38], dtype=int64),
#   array([  32,    9,    0, 1672,   40], dtype=int64),
#   array([52, 10,  0,  0, 55], dtype=int64),
#   array([30,  6,  0,  0, 40], dtype=int64),
#   array([55,  9,  0,  0, 50], dtype=int64),
#   array([24,  7,  0,  0, 40], dtype=int64),
#   array([30,  7,  0,  0, 30], dtype=int64),
#   array([54, 10,  0,  0, 40], dtype=int64),
#   array([27, 14,  0,  0, 52], dtype=int64),
#   array([   52,    14, 15024,     0,    50], dtype=int64),
#   array([58, 13,  0,  0, 55], dtype=int64),
#   array([35,  9,  0,  0, 35], dtype=int64),
#   array([45, 13,  0,  0, 40], dtype=int64),
#   array([20, 10,  0,  0,  8], dtype=int64),
#   array([51, 13,  0,  0, 40], dtype=int64),
#   array([20, 10,  0,  0, 25], dtype=int64),
#   array([  35,   10, 2407,    0,   40], dtype=int64),
#   array([38, 10,  0,  0, 43], dtype=int64),
#   array([74,  4,  0,  0, 35], dtype=int64),
#   array([39, 13,  0,  0, 40], dtype=int64),
#   array([21, 10,  0,  0, 27], dtype=int64),
#   array([24,  9,  0,  0, 35], dtype=int64),
#   array([26, 13,  0,  0, 40], dtype=int64),
#   array([50, 10,  0,  0, 40], dtype=int64),
#   array([31,  9,  0,  0, 42], dtype=int64),
#   array([20, 10,  0,  0, 72], dtype=int64),
#   array([58, 10,  0,  0, 60], dtype=int64),
#   array([25, 14,  0,  0, 40], dtype=int64),
#   array([76,  9,  0,  0, 30], dtype=int64),
#   array([45, 10,  0,  0, 40], dtype=int64),
#   array([22, 10,  0,  0, 25], dtype=int64),
#   array([42, 14,  0,  0, 45], dtype=int64),
#   array([33,  9,  0,  0, 40], dtype=int64),
#   array([  32,   10, 4865,    0,   40], dtype=int64),
#   array([51,  9,  0,  0, 40], dtype=int64),
#   array([44,  9,  0,  0, 24], dtype=int64),
#   array([  45,   14, 1506,    0,   45], dtype=int64),
#   array([47,  9,  0,  0, 32], dtype=int64),
#   array([24, 12,  0,  0, 50], dtype=int64),
#   array([  53,   14, 2174,    0,   40], dtype=int64),
#   array([25,  9,  0,  0, 47], dtype=int64),
#   array([47,  9,  0,  0, 30], dtype=int64),
#   array([23, 10,  0,  0, 30], dtype=int64),
#   array([47, 10,  0,  0, 45], dtype=int64),
#   array([38, 13,  0,  0, 40], dtype=int64),
#   array([45, 10,  0,  0, 40], dtype=int64),
#   array([25, 12,  0,  0, 40], dtype=int64),
#   array([29, 13,  0,  0, 40], dtype=int64),
#   array([24,  9,  0,  0, 40], dtype=int64),
#   array([46,  2,  0,  0, 40], dtype=int64),
#   array([  44,   14, 7298,    0,   40], dtype=int64),
#   array([25,  9,  0,  0, 40], dtype=int64),
#   array([  34,    9, 7443,    0,   35], dtype=int64),
#   array([25, 13,  0,  0, 40], dtype=int64),
#   array([42, 13,  0,  0, 40], dtype=int64),
#   array([19,  9,  0,  0, 40], dtype=int64),
#   array([  34,   10, 7298,    0,   40], dtype=int64),
#   array([22, 10,  0,  0, 20], dtype=int64),
#   array([37,  9,  0,  0, 55], dtype=int64),
#   array([32,  9,  0,  0, 45], dtype=int64),
#   array([63,  9,  0,  0, 40], dtype=int64),
#   array([55,  9,  0,  0, 40], dtype=int64),
#   array([55,  5,  0,  0, 55], dtype=int64),
#   array([23,  9,  0,  0, 40], dtype=int64),
#   array([30,  9,  0,  0, 40], dtype=int64),
#   array([25,  9,  0,  0, 40], dtype=int64),
#   array([  52,   14,    0, 1848,   40], dtype=int64),
#   array([  44,   10, 5178,    0,   60], dtype=int64),
#   array([27,  9,  0,  0, 40], dtype=int64),
#   array([22, 10,  0,  0, 36], dtype=int64),
#   array([   69,    13, 20051,     0,    45], dtype=int64),
#   array([26, 13,  0,  0, 40], dtype=int64),
#   array([58,  9,  0,  0, 40], dtype=int64),
#   array([42, 14,  0,  0, 45], dtype=int64),
#   array([43,  5,  0,  0, 40], dtype=int64),
#   array([  48,   10, 2407,    0,   40], dtype=int64),
#   array([26, 13,  0,  0, 40], dtype=int64),
#   array([54, 13,  0,  0, 40], dtype=int64),
#   array([28,  9,  0,  0, 43], dtype=int64),
#   array([56, 13,  0,  0, 30], dtype=int64),
#   array([58,  9,  0,  0, 55], dtype=int64),
#   array([54,  9,  0,  0, 40], dtype=int64),
#   array([50, 13,  0,  0, 43], dtype=int64),
#   array([   60,     9, 10520,     0,    40], dtype=int64),
#   array([30,  9,  0,  0, 60], dtype=int64),
#   array([39,  9,  0,  0, 55], dtype=int64),
#   array([46, 13,  0,  0, 25], dtype=int64),
#   array([38, 15,  0,  0, 60], dtype=int64),
#   array([  32,    9, 3103,    0,   40], dtype=int64),
#   array([31,  9,  0,  0, 40], dtype=int64),
#   array([27,  5,  0,  0, 40], dtype=int64),
#   array([39,  5,  0,  0, 40], dtype=int64),
#   array([34,  9,  0,  0, 40], dtype=int64),
#   array([   30,    14, 15024,     0,    60], dtype=int64),
#   array([62,  9,  0,  0, 54], dtype=int64),
#   array([33, 13,  0,  0, 40], dtype=int64),
#   array([23,  8,  0,  0, 21], dtype=int64),
#   array([25, 10,  0,  0, 40], dtype=int64),
#   array([34,  9,  0,  0, 28], dtype=int64),
#   array([33, 10,  0,  0, 40], dtype=int64),
#   array([  45,   14,    0, 1977,   60], dtype=int64),
#   array([  27,    9, 2885,    0,   40], dtype=int64),
#   array([35,  9,  0,  0, 20], dtype=int64),
#   array([48,  9,  0,  0,  8], dtype=int64),
#   array([18,  6,  0,  0, 27], dtype=int64),
#   array([24,  2,  0,  0, 40], dtype=int64),
#   array([41, 10,  0,  0, 48], dtype=int64),
#   array([54,  9,  0,  0, 40], dtype=int64),
#   array([   50,    16, 99999,     0,    50], dtype=int64),
#   array([39, 10,  0,  0, 35], dtype=int64),
#   array([23, 13,  0,  0, 40], dtype=int64),
#   array([52,  9,  0,  0, 40], dtype=int64),
#   array([46, 13,  0,  0, 40], dtype=int64),
#   array([  31,   13,    0, 1980,   60], dtype=int64),
#   array([54, 13,  0,  0, 45], dtype=int64),
#   array([26,  9,  0,  0, 40], dtype=int64),
#   array([41,  7,  0,  0, 40], dtype=int64),
#   array([51,  9,  0,  0, 40], dtype=int64),
#   array([35,  5,  0,  0, 50], dtype=int64),
#   array([36,  4,  0,  0, 40], dtype=int64),
#   array([32, 13,  0,  0, 48], dtype=int64),
#   array([31, 10,  0,  0, 45], dtype=int64),
#   array([18,  9,  0,  0, 25], dtype=int64),
#   array([52, 10,  0,  0, 45], dtype=int64),
#   array([31,  9,  0,  0, 36], dtype=int64),
#   array([  42,   10,    0, 1628,   40], dtype=int64),
#   array([33, 10,  0,  0, 45], dtype=int64),
#   array([46,  9,  0,  0, 40], dtype=int64),
#   array([36, 13,  0,  0, 40], dtype=int64),
#   array([  62,    9, 6418,    0,   40], dtype=int64),
#   array([   43,    14, 15024,     0,    32], dtype=int64),
#   array([  38,   11,    0, 1902,   40], dtype=int64),
#   array([32,  9,  0,  0, 35], dtype=int64),
#   array([34, 14,  0,  0, 40], dtype=int64),
#   array([36,  9,  0,  0, 25], dtype=int64),
#   array([41, 15,  0,  0, 45], dtype=int64),
#   array([64, 10,  0,  0, 40], dtype=int64),
#   array([44,  9,  0,  0, 40], dtype=int64),
#   array([30,  9,  0,  0, 40], dtype=int64),
#   array([19,  9,  0,  0, 40], dtype=int64),
#   array([  25,   12, 3103,    0,   45], dtype=int64),
#   array([   71,    11, 11678,     0,    38], dtype=int64),
#   array([41, 13,  0,  0, 40], dtype=int64),
#   array([  30,   10,    0, 1848,   40], dtype=int64),
#   array([26,  9,  0,  0, 40], dtype=int64),
#   array([38, 13,  0,  0, 45], dtype=int64),
#   array([61,  9,  0,  0, 20], dtype=int64),
#   array([29, 12,  0,  0, 50], dtype=int64),
#   array([32,  7,  0,  0, 40], dtype=int64),
#   array([64,  9,  0,  0, 40], dtype=int64),
#   array([28, 10,  0,  0, 40], dtype=int64),
#   array([22,  9,  0,  0, 40], dtype=int64),
#   array([  30,   10, 3325,    0,   40], dtype=int64),
#   array([24, 11,  0,  0, 30], dtype=int64),
#   array([46,  9,  0,  0, 40], dtype=int64),
#   array([  38,   13, 3908,    0,   70], dtype=int64),
#   array([37, 10,  0,  0, 40], dtype=int64),
#   array([67, 10,  0,  0, 44], dtype=int64),
#   array([44, 13,  0,  0, 36], dtype=int64),
#   array([72, 13,  0,  0, 40], dtype=int64),
#   array([25,  9,  0,  0, 35], dtype=int64),
#   array([20,  9,  0,  0, 40], dtype=int64),
#   array([35, 11,  0,  0, 40], dtype=int64),
#   array([58, 13,  0,  0, 40], dtype=int64),
#   array([51, 12,  0,  0, 30], dtype=int64),
#   array([37,  9,  0,  0, 48], dtype=int64),
#   array([21,  9,  0,  0, 40], dtype=int64),
#   array([30, 10,  0,  0, 55], dtype=int64),
#   array([  29,   13,    0, 1902,   50], dtype=int64),
#   array([60, 10,  0,  0, 15], dtype=int64),
#   array([68,  9,  0,  0, 40], dtype=int64),
#   array([40, 13,  0,  0, 50], dtype=int64),
#   array([29, 13,  0,  0, 40], dtype=int64),
#   array([56,  6,  0,  0, 45], dtype=int64),
#   array([30,  9,  0,  0, 14], dtype=int64),
#   array([24, 10,  0,  0, 40], dtype=int64),
#   array([20, 10,  0,  0, 12], dtype=int64),
#   array([   55,    13, 15024,     0,    42], dtype=int64),
#   array([51,  7,  0,  0, 40], dtype=int64),
#   array([36,  9,  0,  0, 30], dtype=int64),
#   array([34,  9,  0,  0, 65], dtype=int64),
#   array([65,  4,  0,  0, 50], dtype=int64),
#   array([22, 12,  0,  0, 45], dtype=int64),
#   array([  47,   13,    0, 1740,   40], dtype=int64),
#   array([39,  9,  0,  0, 40], dtype=int64),
#   array([22, 10,  0,  0, 30], dtype=int64),
#   array([63, 13,  0,  0, 40], dtype=int64),
#   array([  50,    9, 3103,    0,   40], dtype=int64),
#   array([35,  9,  0,  0, 27], dtype=int64),
#   array([26,  9,  0,  0, 40], dtype=int64),
#   array([21,  9,  0,  0, 60], dtype=int64),
#   array([38, 13,  0,  0, 40], dtype=int64),
#   array([42,  9,  0,  0, 40], dtype=int64),
#   array([51, 16,  0,  0, 60], dtype=int64),
#   array([30, 14,  0,  0, 45], dtype=int64),
#   array([54,  3,  0,  0, 51], dtype=int64),
#   array([50,  6,  0,  0, 40], dtype=int64),
#   array([  33,    9,    0, 1740,   25], dtype=int64),
#   array([33, 14,  0,  0, 70], dtype=int64),
#   array([   45,    16, 15020,     0,    40], dtype=int64),
#   array([36,  7,  0,  0, 43], dtype=int64),
#   array([23, 13,  0,  0, 35], dtype=int64),
#   array([18,  9,  0,  0, 25], dtype=int64),
#   array([28,  9,  0,  0, 40], dtype=int64),
#   array([  34,    9,    0, 1672,   40], dtype=int64),
#   array([48, 10,  0,  0, 40], dtype=int64),
#   array([54,  9,  0,  0, 40], dtype=int64),
#   array([73,  9,  0,  0, 24], dtype=int64),
#   array([30,  6,  0,  0, 40], dtype=int64),
#   array([45,  9,  0,  0, 40], dtype=int64),
#   array([48, 13,  0,  0, 60], dtype=int64),
#   array([50,  9,  0,  0, 40], dtype=int64),
#   array([55, 13,  0,  0, 55], dtype=int64),
#   array([28, 10,  0,  0, 40], dtype=int64),
#   array([30, 13,  0,  0, 40], dtype=int64),
#   array([50, 10,  0,  0, 35], dtype=int64),
#   array([44, 10,  0,  0, 25], dtype=int64),
#   array([28, 13,  0,  0, 40], dtype=int64),
#   array([38, 14,  0,  0, 50], dtype=int64),
#   array([20, 10,  0,  0, 20], dtype=int64),
#   array([47, 10,  0,  0, 25], dtype=int64),
#   array([48,  9,  0,  0, 40], dtype=int64),
#   array([45,  9,  0,  0, 40], dtype=int64),
#   array([  75,    9,    0, 2467,   40], dtype=int64),
#   array([37,  9,  0,  0, 37], dtype=int64),
#   array([62,  5,  0,  0, 40], dtype=int64),
#   array([  44,   10, 5178,    0,   40], dtype=int64),
#   array([   40,    15, 15024,     0,    45], dtype=int64),
#   array([34,  9,  0,  0, 40], dtype=int64),
#   array([28,  9,  0,  0, 40], dtype=int64),
#   array([38,  9,  0,  0, 40], dtype=int64),
#   array([39, 13,  0,  0, 20], dtype=int64),
#   array([29, 16,  0,  0, 40], dtype=int64),
#   array([52, 14,  0,  0, 40], dtype=int64),
#   array([32, 13,  0,  0, 40], dtype=int64),
#   array([66,  9,  0,  0, 35], dtype=int64),
#   array([  52,   10, 7298,    0,   45], dtype=int64),
#   array([23, 10,  0,  0, 25], dtype=int64),
#   array([36,  3,  0,  0, 40], dtype=int64),
#   array([29, 10,  0,  0, 65], dtype=int64),
#   array([23, 10,  0,  0, 20], dtype=int64),
#   array([24,  9,  0,  0, 40], dtype=int64),
#   array([28,  9,  0,  0, 40], dtype=int64),
#   array([45, 10,  0,  0, 48], dtype=int64),
#   array([20,  9,  0,  0, 40], dtype=int64),
#   array([68,  9,  0,  0, 10], dtype=int64),
#   array([  43,   10,    0, 1485,   50], dtype=int64),
#   array([27, 13,  0,  0, 40], dtype=int64),
#   array([46, 14,  0,  0, 40], dtype=int64),
#   array([29, 14,  0,  0, 50], dtype=int64),
#   array([30,  9,  0,  0, 40], dtype=int64),
#   array([32, 12,  0,  0, 45], dtype=int64),
#   array([42, 11,  0,  0, 45], dtype=int64),
#   array([18, 10,  0,  0, 40], dtype=int64),
#   array([25, 10,  0,  0, 40], dtype=int64),
#   array([37, 11,  0,  0, 54], dtype=int64),
#   array([32,  9,  0,  0, 40], dtype=int64),
#   array([38, 16,  0,  0, 40], dtype=int64),
#   array([57, 14,  0,  0, 45], dtype=int64),
#   array([43,  9,  0,  0, 40], dtype=int64),
#   array([34, 13,  0,  0, 40], dtype=int64),
#   array([36,  9,  0,  0, 40], dtype=int64),
#   array([47, 10,  0,  0, 40], dtype=int64),
# ...
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(0, dtype=int64),
#   array(1, dtype=int64),
#   ...])

# %%
from sklearn.cluster import KMeans
from collections import Counter, defaultdict

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import Sequential
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# %%
class TrainingModel:
    def __init__(self, input_shape):
        self.model = Sequential()
        self.model.add(Dense(64, activation='relu', input_shape=input_shape))
        self.model.add(Dropout(0.3))
        self.model.add(Dense(128, activation='relu'))
        self.model.add(Dropout(0.3))
        self.model.add(Dense(128, activation='relu'))
        self.model.add(Dense(1, activation='sigmoid'))
        self.model.compile(optimizer='adam', 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

    def fit(self, data, label):
        self.model.fit(data, label, epochs=1, batch_size=128, verbose=0)

    def predict(self, data):
        return self.model.predict_classes(data)
    
    def evaluate(self, X_test, y_test, print_report=True):
        y_predicted = self.predict(X_test)
        y_predicted_probs = self.model.predict_proba(X_test)
        if print_report:
            self.print_report(y_test, y_predicted, y_predicted_probs)
        else:
            accuracy = accuracy_score(y_test, y_predicted)
            report = classification_report(y_test, y_predicted, output_dict=True)
            auc_score = roc_auc_score(y_test, y_predicted_probs)
            matrix = confusion_matrix(y_test, y_predicted)

            return {
                'accuracy': accuracy,
                'auc_score': auc_score,
                **report['weighted avg'],
            }

    def print_report(self, test, predicted, predicted_probs):
        accuracy = accuracy_score(test, predicted)
        report = classification_report(test, predicted)
        matrix = confusion_matrix(test, predicted)

        print('Accuracy score: {:.5f}'.format(accuracy))
        print('-' * 20)
        print('Confusion Matrix:')
        print(matrix)
        print('-' * 20)
        print(report)
        print('-' * 20)
        print('AUC score: {:.5f}'.format(roc_auc_score(test, predicted_probs)))

# %% [markdown]
# # K means + Model

# %%
#將SOM資料集丟入Kmeans
#Kmeans分群數依照k值(k-anonymity的k)決定，從K = x/k開始遞減直到每一群至少有k筆資料
#計算跑的時間

sizes = [5, 10, 15, 20, 30, 50]
#k = 5
#K = int(len(new_data[0])/k)
#cluster = True
#c = Counter()

for k in sizes:
    
    perturb_start=datetime.now()
    
    print("K-Anonymity: k=" + str(k))
    K = int(len(new_data[0])/k)
    cluster = True
    while cluster:
        clf = KMeans(n_clusters=K)
        clf.fit(new_data[0])
        c = Counter(clf.labels_)
        print("K=" + str(K))
        for i in range(0,K):
            print("cluster " + str(i) + " has " + str(c[i]) + " data points")
            if c[i]<k:
                break
            else:
                if i == K-1:
                    cluster = False
                else:
                    pass
        K = K-1
    K = K+1
    print("The Resulting number of clusters: " + str(K))
    
    #將分完群的資料還原回原始資料的feature
    #準備丟入神經網路

    data = pd.concat([pd.DataFrame(new_data[1],columns=['age', 'educational-num','capital-gain', 'capital-loss', 'hours-per-week']), 
                      pd.DataFrame(new_data[2],columns=['target']), pd.DataFrame(clf.labels_,columns=['cluster'])], axis = 1)
    columns = ['age', 'educational-num','capital-gain', 'capital-loss', 'hours-per-week','target','cluster']
    index = range(0,len(data))
    data_perturbed = pd.DataFrame(index = index, columns=columns)

    for i in range(0, len(data)):
        for j in range(0,K+1):
            if data['cluster'][i] == j:
                data_perturbed[columns[0]][i] = float(data.groupby(by='cluster').mean()[columns[0]][j])
                data_perturbed[columns[1]][i] = float(data.groupby(by='cluster').mean()[columns[1]][j])
                data_perturbed[columns[2]][i] = float(data.groupby(by='cluster').mean()[columns[2]][j])
                data_perturbed[columns[3]][i] = float(data.groupby(by='cluster').mean()[columns[3]][j])
                data_perturbed[columns[4]][i] = float(data.groupby(by='cluster').mean()[columns[4]][j])
                data_perturbed['target'][i] = data['target'][i]
                data_perturbed['cluster'][i] = data['cluster'][i]

    data_sorted = data_perturbed.sort_values(by=['cluster'])
    data_ready = data_sorted.drop('cluster', axis=1)
    
    print("Time required for perturbation: " + str(datetime.now()-perturb_start_start))
    
    X_train, X_test, y_train, y_test = train_test_split(data_ready.iloc[:,0:5], data_ready.iloc[:,5:], test_size=0.2)
    model = TrainingModel((5,))
    model.fit(X_train, y_train)
    print(model.predict(X_test))
